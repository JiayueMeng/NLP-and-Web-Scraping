# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import tensorflow.keras
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
import math
from math import log
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#This is the result for testing between Physics and History apartment of Vanderbilt. 
#The dataset has a total size of 75,
#while 42 is form History and 33 is from Physics.
#We chose 20 words that matters the most to form the dataset, 
#and label data from History as "1", data from Physics as "2".

# %%
#This is the part to do some basic process about the dataset. For the firt 15 rows, which is the data from history,
#add in a label "1". And for the following 15 rows, which is the data from Physics, add in a label "2".
#Then, to merge the two datasets (History + Physics) to get the final dataset.

# %%
smalltest = pd.read_csv("Vantest.csv") #Import the dataset.
#smalltest.drop(index = 0, inplace=True)
smalltest = smalltest.drop('Unnamed: 0', axis = 1)
filt = smalltest.iloc[0:42] #Get the first 42 rows (data for History)
filt['output'] = [1 for row in range(len(filt))] #Add in a label "1" for the first 15 rows
filt2 = smalltest.iloc[42:75] #Get the next 33 rows (data for Physics)
filt2['output'] = [2 for row in range(len(filt2))] #Add in a label "2" for the next 15 rows
smalltest = pd.merge(filt, filt2, how = 'outer') #Merge the two datasets for History and Physics
smalltest
# Out:
#       history  university  vanderbilt    physics   studies  latin      book  \
# 0   30.653333   -3.723175   -1.351111  -0.000000  0.970159   -0.0 -0.323333
# 1   18.364622    2.041353    6.115445  -0.000000  8.860643   -0.0  3.022120
# 2   99.066427   -1.991090    0.634173  -0.000000 -0.111405   -0.0  0.320549
# 3    5.850966   19.098379    2.226080  -0.000000 -0.284528   -0.0 -0.351072
# 4   68.454195    8.441843    1.381864  -0.000000 -0.096237   -0.0  0.439736
# ..        ...         ...         ...        ...       ...    ...       ...
# 70  -0.000000    2.518109   19.290148  14.724069 -0.000000   -0.0 -0.000000
# 71  -0.000000    3.162554   14.419613  10.224582 -0.000000   -0.0 -0.000000
# 72  -0.000000   17.914997   12.039187  16.407127 -0.000000   -0.0 -0.000000
# 73  -0.000000    3.375198   14.706829  10.407914 -0.000000   -0.0 -0.000000
# 74  -0.000000   13.585689   16.742145  12.492233 -0.000000   -0.0 -0.000000
#
#          law  information     fellow  ...    program   courses  department  \
# 0  -0.071429    -0.026667  -0.000000  ...  -0.278730  0.409524   -0.318889
# 1  -0.083729    -0.004447  -0.000000  ...   0.186491  6.734483   -0.367656
# 2  -0.039001     0.010629   0.856689  ...  -0.149725  1.425592   -0.168317
# 3   3.065731     2.068336  -0.000000  ...  -0.334136 -0.470559   -0.369356
# 4  -0.045910     0.052373   0.142073  ...  -0.186184 -0.257344    3.059452
# ..       ...          ...        ...  ...        ...       ...         ...
# 70 -0.000000     3.955204  18.134070  ...   3.979958  2.650527    8.610867
# 71 -0.000000     4.832837  -0.000000  ...   4.862583  3.243551    4.033783
# 72 -0.000000     4.039132   4.133882  ...   4.063586  2.715382   16.570995
# 73 -0.000000     4.933690  -0.000000  ...  10.572690  3.321557    4.115642
# 74 -0.000000     2.213688  52.095096  ...   2.224855  1.492737    1.847873
#
#      society  professor         i   faculty     roman  education  output
# 0   3.610635  -0.000000 -0.000000 -0.106667 -0.000000  -0.000000       1
# 1   4.355485   0.520563 -0.000000 -0.098915 -0.000000  -0.000000       1
# 2  -0.096771  -0.000000 -0.000000 -0.033689 -0.000000  -0.000000       1
# 3  -0.217261   0.579055 -0.000000 -0.047190  2.892537  -0.000000       1
# 4   0.907739  -0.131832  6.051765  3.036353 -0.000000   0.210980       1
# ..       ...        ...       ...       ...       ...        ...     ...
# 70 -0.007453   0.541535 -0.000000  5.746083 -0.000000   0.016663       2
# 71 -0.006776  -0.000000 -0.000000  2.004218 -0.000000   0.022338       2
# 72  1.640124  -0.000000 -0.000000  1.680716 -0.000000   0.020305       2
# 73  0.002521  -0.000000 -0.000000  2.058951 -0.000000   0.026735       2
# 74  6.687733   1.518583 -0.000000  0.926825 -0.000000   0.693146       2
#
# [75 rows x 21 columns]

# %%
#This is the part to separate training set and testing set. I would pick a size of 10 as testing set, which includes
#5 data from History and 5 data from Physics.

# %%
#testing set
test_x = smalltest.iloc[36:46] #I would directly pick row 36 to row 45 a teting set.
test_y = np.array(test_x['output'])
test_x = test_x.drop('output', axis = 1)
test_x = np.array(test_x)
#training set
train_x_1 = smalltest.iloc[0:36] #The training set would then be row 0-35, and row 46-74. Merge then to get the training set.
train_x_2 = smalltest.iloc[46:75]
train_x = pd.merge(train_x_1, train_x_2, how = 'outer')
train_y = np.array(train_x['output'])
train_x = train_x.drop('output', axis = 1)
train_x = np.array(train_x)
train_y = np.array(train_y)

# %%
test_y
# Out:
# array([1, 1, 1, 1, 1, 1, 2, 2, 2, 2])

# %%
#This is the part for SVM. We used the function .SVC directly since it's convenient and powerful.

# %%
#SVM
from sklearn import svm
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.datasets import make_blobs
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
#For kernel function, we just pick "linear". We found out that the accuracy of linear function is already 100%,
#and we don't think we need to make the model more complicated by choosing another kernel function while linear function 
#can already work really well. For C, we just pick 100. We tried to test different C, like 0.01, 1, 100, 10000, but 
#there isn't much difference in the result. Therefore, we just picked 100.

# %%
lin = svm.SVC(kernel = 'linear', C = 100)
lin.fit(train_x, train_y)
predict = lin.predict(test_x)
acc_num = sum(predict == test_y)
acc_num
# Out:
# 10

# %%
#This is the part to show final result. Predict shows the array of predicted result. 
#Accuracy show the percentage of accuracy.
#confusion_matrix would draw a confusion matrix which represents our result.

# %%
print("Predict:", predict)
print("Accuracy:" , acc_num/10)
confusion_matrix(test_y, predict)
# Out:
# Predict: [1 1 1 1 1 1 2 2 2 2]
# Accuracy: 1.0
# array([[6, 0],
#        [0, 4]])
