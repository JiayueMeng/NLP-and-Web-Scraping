# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/news_all.csv")
df[df["title"].str.contains("Vermont")==True]
# Out:
#       Unnamed: 0 newspaper  category  \
# 4              4       abc     sport
# 133          133       abc      tech
# 264          264       abc  business
# 396          396       abc  politics
# 545          545       fox     sport
# 751          751       fox      tech
# 1218        1218       fox  politics
# 2446        2446       cnn     sport
# 2978        2978       cnn      tech
# 3510        3510       cnn  business
# 4040        4040       cnn  politics
#
#                                                   title  \
# 4     Tuesday's primaries could set up history in Ve...
# 133   Tuesday's primaries could set up history in Ve...
# 264   Tuesday's primaries could set up history in Ve...
# 396   Tuesday's primaries could set up history in Ve...
# 545   Vermont to choose congressional candidates, in...
# 751   Vermont to choose congressional candidates, in...
# 1218  Vermont to choose congressional candidates, in...
# 2446  'The Flash' actor Ezra Miller cited for felony...
# ...

# %%
df = df[df["keywords"].str.contains("video")==False]
#df = df.reset_index()
#df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      newspaper  category                                              title  \
# 0          abc     sport  Gun buyback program sees more than 845 guns tu...
# 1          abc     sport  House committee can obtain Trump tax returns f...
# 2          abc     sport  Mike Pompeo, Doug Mastriano being interviewed ...
# 3          abc     sport  Biden signs CHIPS Act, intended to relieve the...
# 4          abc     sport  Tuesday's primaries could set up history in Ve...
# ...        ...       ...                                                ...
# 4228       cnn  politics  The flat-pack electric OX Truck is making deli...
# 4229       cnn  politics  Africa's next big thing will be its tech start...
# 4230       cnn  politics  Nigeria is oil rich and energy poor. It can't ...
# 4231       cnn  politics  Meet the Nigerian visual artist turning coffee...
# 4232       cnn  politics  Palestinians vow to stay on West Bank land des...
#
# ...

# %%
df.to_csv("C:/Users/Joyce/Desktop/nlp/news_all.csv")

# %%
df = pd.read_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/cnn.csv")
df = df[df["keywords"].str.contains("video")==False]
#df = df.reset_index()
#df = df.drop('Unnamed: 0', axis=1)
df.to_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/cnn.csv")

# %%
# df = pd.read_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/abc.csv")
# df = df[df["keywords"].str.contains("video")==False]
#df = df.reset_index()
# df = df.drop('Unnamed: 0.1', axis=1)
# df = df.drop('index', axis=1)
# df = df.drop('Unnamed: 0', axis=1)
# df
df.to_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/abc.csv")

# %%
# df = pd.read_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/nbc.csv")
# df = df[df["keywords"].str.contains("video")==False]
# df = df.reset_index()
# # df = df.drop('Unnamed: 0.1', axis=1)
# df = df.drop('index', axis=1)
# df = df.drop('Unnamed: 0', axis=1)
# df
df.to_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/nbc.csv")

# %%
# df = pd.read_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/fox.csv")
# df = df[df["keywords"].str.contains("video")==False]
# df = df.reset_index()
# # df = df.drop('Unnamed: 0.1', axis=1)
# df = df.drop('index', axis=1)
# df = df.drop('Unnamed: 0', axis=1)
# df
df.to_csv("C:/Users/Joyce/Desktop/nlp/All_News_Linda/fox.csv")
